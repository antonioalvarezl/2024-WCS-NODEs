# %% [markdown]
# # Binary classification
#
# Objective:
# For $d$ and $N$ given, find the complexity (number of discontinuities $L$) required by the control functions $(w,a,b)$ of a neural ODE
# \begin{equation}
# \dot x = w(t)\sigma(a(t)\cdot x+b(t)),\qquad t\in(0,T)
# \end{equation}
# to classify a dataset $\{(x_i,y_i)\}_{i=1}^N$, where $x_i\sim U([0,1]^d)$ and $y_i\in\{0,1\}$ are randomly chosen for all $i$.
#
# Classification is understood as finding some controls $(w,a,b)$ such that the flow map $\Phi_T$ of the neural ODE satisfies
# \begin{equation*}
# \Phi_T(x_i;w,a,b)^{(d)}>1\quad\text{for all }x_i\text{ such that }y_i=1,
# \end{equation*}
# and
# \begin{equation*}
# \Phi_T(x_i;w,a,b)^{(d)}<1\quad\text{for all }x_i\text{ such that }y_i=0.
# \end{equation*}
# Also, study the dependence of $L$ with $d$ and $N$.

# %%
import torch
import os
import json
from math import ceil
import random
from IPython.display import Image, display, clear_output

from Functions.training import Trainer
from Functions.neural_odes import NeuralODE
from Functions.plots import plot_data, plot_logloss, levelsets
from Functions.create import create_dataloader, create_paths, create_projector
from Functions.tables import dataframe
from Functions.gifs import traj_gif, select_random_samples

# Set the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Matplotlib inline for IPython
# %matplotlib inline

# Ensure reproducibility
torch.backends.cudnn.deterministic = True

def reset_seed(seed):
    torch.manual_seed(seed) # Set the seed for the random number generator
    torch.cuda.manual_seed(seed) # Set the seed for the operations in the GPU
    g = torch.Generator()
    g.manual_seed(seed)

# %% [markdown]
# # Initialization of variables (data, dynamics, training)
# The dynamics are based on the torchdiffeq package, which implements ODE solvers in the PyTorch setting

# %%
# Define dataset

distribution = 'uniformbalanced'  # Options: circles, blobs, moons, xor, uniform, uniformbalanced
N = 20  # Number of data points
d = 2  # Dimension of the data
rescale = True  # Rescale data to mean 0 and variance 1

# Define dynamics

L = 5  # Number of discontinuities
hidden_dim = 1
T, num_vals = 20, L+1 
non_linearity = 'trunrelu'  # Options: relu, tanh, sigmoid, leakyrelu, trunrelu, 2relu
architecture = 'bottleneck'  # Options: inside, outside, bottleneck
final_layer = True  # Add a final linear layer if output_dim = 1

# Define ODE solver
method = 'euler'  # Options: euler, midpoint, dopri5, rk4
step_size = 0.05 * T / num_vals  # Step size for the ODE solver

# Display setup information
print(f'Data: {N} points from {distribution} in R^{d} - Dynamics: {non_linearity} - Architecture: {architecture}')
print(f'Complexity: L={num_vals-1} discontinuities')
print(f'Complexity in the constructive algorithm: L_0 = {2 * ceil(N / (2 * d)) - 1} discontinuities')

# Define training parameters
learning_rate = 1e-3
max_epochs = 30000  # Maximum number of epochs per training session
max_count = 1  # Maximum number of trials per dataset seed
verbose, adjoint = True, False  # Print loss at each epoch, use odeint_adjoint if True
loss_func = 'mse'  # Loss function: cross_entropy, mse, bce, linear_sep

output_dim = 2 if loss_func == 'cross_entropy' else 1
final_layer = True if output_dim == 1 else final_layer

print(f'Loss: {loss_func} - Max epochs: {max_epochs} - Learning rate: {learning_rate} - Step size: {step_size}')

# Additional options
noise = 0
fixed_projector = True  # Fix the linear layer if True
random_projector = False  # Use random weights for the fixed projector if True

if final_layer and fixed_projector:
    fixed_projector = create_projector(device, d, output_dim, random_projector)
    print(f'Fixed projector weights: \n{fixed_projector.weight} \n{fixed_projector.bias}')

def reset_seed(seed):
    torch.manual_seed(seed) # Set the seed for the random number generator
    torch.cuda.manual_seed(seed) # Set the seed for the operations in the GPU
    g = torch.Generator()
    g.manual_seed(seed)
# Out:
# Data: 20 points from uniformbalanced in R^2 - Dynamics: trunrelu - Architecture: bottleneck
# Complexity: L=5 discontinuities
# Complexity in the constructive algorithm: L_0 = 9 discontinuities
# Loss: mse - Max epochs: 30000 - Learning rate: 0.001 - Step size: 0.16666666666666666
# Fixed projector weights:
# Parameter containing:
# tensor([[0., 1.]])
# Parameter containing:
# tensor([-0.5000])

# %% [markdown]
# # Dynamics and Training

# %%
# Run the training loop
for k in range(1):
    seed_data, seed_train = k, 0
    classif = False
    count = 0

    # Create dataset
    datatrain, y, X0, X1 = create_dataloader(distribution, N=N, d=d, noise=noise, seed=seed_data, rescale=rescale)
    print(f'blue: {X0.shape}, red: {X1.shape}')

    while not classif and count < max_count:
        seed_params = 951 # random.randint(1, 1000)
        
        # Setup paths and plotting options
        export_fig, record_freq = True, 20
        if export_fig:
            full_path = create_paths(non_linearity, architecture, d, hidden_dim, num_vals, distribution, N, seed_data, seed_params, rescale)
        
        # Initialize and train the Neural ODE
        print("Training Neural ODE")
        node = NeuralODE(device, fixed_projector, d, hidden_dim, output_dim, non_linearity, adjoint, 
                         architecture, T, num_vals, step_size, method, final_layer, seed_params)
        optimizer = torch.optim.Adam(node.parameters(), lr=learning_rate)
        trainer = Trainer(node, optimizer, device, fixed_projector, loss_func, AdjTrainer=False,
                                    record_freq=record_freq, pathgifs=full_path, verbose=verbose)
        trainer.train(datatrain, max_epochs, full_path)
        
        # Save initial parameters
        variables = [seed_data, seed_params, N, hidden_dim, d, T, num_vals, step_size, learning_rate, non_linearity, loss_func, architecture, max_epochs, random_projector]
        variable_names = ['seed_data', 'seed_params', 'N', 'hidden_dim', 'd', 'T', 'num_vals', 'step_size', 'learning_rate', 'non_linearity', 'loss_func', 'architecture', 'max_epochs', 'Random projector']
        with open(os.path.join(full_path, "InitialValues.json"), "w") as f:
            json.dump(dict(zip(variable_names, variables)), f)
        
        clear_output(wait=True)
        
        # Plot loss and data
        plot_logloss(trainer, full_path, export_fig=True)
        inputs, targets = [], []
        for batch_points, batch_labels in datatrain:
            inputs.append(batch_points)
            targets.append(batch_labels)
        inputs, targets = torch.cat(inputs), torch.cat(targets)
        
        initpts_path = plot_data(node, inputs, targets, N, dpi=400, alpha=0.9, path=full_path, controls = True, init=True, rescale=rescale)
        finalpts_path = plot_data(node, inputs, targets, N, dpi=400, alpha=0.9, path=full_path, controls = True, plot_targets = False, final=True)
        display(Image(filename=initpts_path, width=1000))
        display(Image(filename=finalpts_path, width=1000))
        
        # Visualization of level sets (if d=2)
        # levelsets(node, path=full_path, fig_name=f'Level set',rescale = rescale, step = 0.01, dpi = 800, points = (X0,X1))
        
        # Visualization of trajectories (if d=2)
        num_samples = N  # Number of input points to plot the trajectories
        # inputs, targets = select_random_samples(datatrain, num_samples)
        traj_gif(node, inputs, targets, dpi = 400, path = full_path, fps = 10)
        
        # Summarize the results in a dataframe
        dataframe(trainer, full_path)
        
        if trainer.classif:
            classif = True
            dir_name, file_name = os.path.split(full_path)
            base, ext = os.path.splitext(file_name)
            new_file_name = f"{base} - Achieved{ext}"
            new_path = os.path.join(dir_name, new_file_name)
            os.rename(full_path, new_path)
            full_path = new_path
        else:
            count += 1
            
    if count == max_count:
        dir_name, file_name = os.path.split(full_path)
        base, ext = os.path.splitext(file_name)
        new_file_name = f"{base} - Failed in {max_count} tests{ext}"
        new_path = os.path.join(dir_name, new_file_name)
        os.rename(full_path, new_path)
        break
# Out:
# blue: (10, 2), red: (10, 2)
# Training Neural ODE
# /Users/antonioalvarezlopez/Downloads/2024-WCS-NODEs-main/Functions/create.py:74: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train_tensor = y.clone().detach() if data_type == 'uniform' else torch.tensor(y, dtype=torch.long)
# Training for up to 30000 epochs with patience 10000
# Optimization method: Adam
# Loss function: mse
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 10/30000 (0.02s). Train loss: 16.863482, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 20/30000 (0.02s). Train loss: 15.541311, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 30/30000 (0.02s). Train loss: 14.283417, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 40/30000 (0.02s). Train loss: 13.132856, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 50/30000 (0.01s). Train loss: 12.118896, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 60/30000 (0.02s). Train loss: 11.126545, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 70/30000 (0.02s). Train loss: 10.248030, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 80/30000 (0.02s). Train loss: 9.476149, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 90/30000 (0.01s). Train loss: 8.786566, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 100/30000 (0.01s). Train loss: 8.172761, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 110/30000 (0.02s). Train loss: 7.633267, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 120/30000 (0.02s). Train loss: 7.154212, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 130/30000 (0.02s). Train loss: 6.716029, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 140/30000 (0.01s). Train loss: 6.311593, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 150/30000 (0.02s). Train loss: 5.934395, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 160/30000 (0.02s). Train loss: 5.579183, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 170/30000 (0.01s). Train loss: 5.243910, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 180/30000 (0.01s). Train loss: 4.925216, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 190/30000 (0.02s). Train loss: 4.622819, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 200/30000 (0.02s). Train loss: 4.330780, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 210/30000 (0.01s). Train loss: 4.046634, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 220/30000 (0.02s). Train loss: 3.768019, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 230/30000 (0.01s). Train loss: 3.492017, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 240/30000 (0.06s). Train loss: 3.217916, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 250/30000 (0.03s). Train loss: 2.942205, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 260/30000 (0.01s). Train loss: 2.671283, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 270/30000 (0.03s). Train loss: 2.409045, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 280/30000 (0.02s). Train loss: 2.142147, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 290/30000 (0.01s). Train loss: 1.897472, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 300/30000 (0.01s). Train loss: 1.686809, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 310/30000 (0.01s). Train loss: 1.528375, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 320/30000 (0.01s). Train loss: 1.410968, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# ...
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 8290/30000 (0.01s). Train loss: 0.082219, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 8300/30000 (0.01s). Train loss: 0.082212, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 8310/30000 (0.01s). Train loss: 0.082205, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 8320/30000 (0.01s). Train loss: 0.082198, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 8330/30000 (0.01s). Train loss: 0.082192, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Epoch 8340/30000 (0.01s). Train loss: 0.082185, Train acc: 0.0000
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# Saving model to Results/uniformbalanced/Sigma=trunrelu_Arch=bottleneck_Width=1/2N=20_Dim=2_L=5_Rescaled/DS0PS951Results1/best_param_NODE.pt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 26
#      23 optimizer = torch.optim.Adam(node.parameters(), lr=learning_rate)
#      24 trainer = Trainer(node, optimizer, device, fixed_projector, loss_func, AdjTrainer=False,
#      25                             record_freq=record_freq, pathgifs=full_path, verbose=verbose)
# ---> 26 trainer.train(datatrain, max_epochs, full_path)
#      28 # Save initial parameters
#      29 variables = [seed_data, seed_params, N, hidden_dim, d, T, num_vals, step_size, learning_rate, non_linearity, loss_func, architecture, max_epochs, random_projector]
#
# File ~/Downloads/2024-WCS-NODEs-main/Functions/training.py:234, in Trainer.train(self, datatrain, max_epochs, pathparams, validation_data, patience, lr_scheduler)
#     231 # Check if perfect classification is achieved on training data
#     232 # This is used as an additional stopping criterion
#     233 with torch.no_grad():
# --> 234     predictions, _ = self.model(points)
#     235     if self.loss_func == 'cross_entropy' and self.model.output_dim > 1:
#     236         predictions = torch.argmax(F.softmax(predictions, dim=1), dim=1)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Downloads/2024-WCS-NODEs-main/Functions/neural_odes.py:266, in NeuralODE.forward(self, x, return_features, i)
#     262     self.flow = Semiflow(self.device, self.fwd_dynamics, self.adjoint,
#     263                         self.T, self.dt, self.method, self.seed_params)
#     265 # Compute the final state and full trajectory
# --> 266 features = self.flow(x)
#     267 traj = self.flow.trajectory(x, int(self.T / self.dt) + 1)
#     269 # Apply final classification layer if specified
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Downloads/2024-WCS-NODEs-main/Functions/neural_odes.py:170, in Semiflow.forward(self, x, eval_times)
#     163     out = odeint_adjoint(self.dynamics, x, integration_time,
#     164                         method=self.method, options={'step_size': self.dt})
#     165     # Alternative with adaptive time stepping:
#     166     # out = odeint_adjoint(self.dynamics, x, integration_time, rtol=0.1, atol=0.1,
#     167     #                      method='dopri5', options={'max_num_steps': MAX_NUM_STEPS})
#     168 else:
#     169     # Standard ODE integration
# --> 170     out = odeint(self.dynamics, x, integration_time,
#     171                 method=self.method, options={'step_size': self.dt})
#     172     # Alternative with adaptive time stepping:
#     173     # out = odeint(self.dynamics, x, integration_time, rtol=0.1, atol=0.1,
#     174     #             method='dopri5', options={'max_num_steps': MAX_NUM_STEPS})
#     175
#     176 # Return final state or full trajectory
#     177 if eval_times is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torchdiffeq/_impl/odeint.py:77, in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      74 solver = SOLVERS[method](func=func, y0=y0, rtol=rtol, atol=atol, **options)
#      76 if event_fn is None:
# ---> 77     solution = solver.integrate(t)
#      78 else:
#      79     event_t, solution = solver.integrate_until_event(t[0], event_fn)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torchdiffeq/_impl/solvers.py:105, in FixedGridODESolver.integrate(self, t)
#     103 for t0, t1 in zip(time_grid[:-1], time_grid[1:]):
#     104     dt = t1 - t0
# --> 105     dy, f0 = self._step_func(self.func, t0, dt, t1, y0)
#     106     y1 = y0 + dy
#     108     while j < len(t) and t1 >= t[j]:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torchdiffeq/_impl/fixed_grid.py:9, in Euler._step_func(self, func, t0, dt, t1, y0)
#       6 class Euler(FixedGridODESolver):
#       7     order = 1
# ----> 9     def _step_func(self, func, t0, dt, t1, y0):
#      10         f0 = func(t0, y0, perturb=Perturb.NEXT if self.perturb else Perturb.NONE)
#      11         return dt * f0, f0
#
# KeyboardInterrupt:

# %% [markdown]
# # LOAD PARAMETERS

# %%
load = False # Change to True for loading the best parameters saved
if load:
    node=NeuralODE(device, fixed_projector, d, hidden_dim, output_dim = output_dim, non_linearity=non_linearity, adjoint=adjoint, 
            architecture=architecture, T=T, num_vals=num_vals, step_size=step_size, method=method, final_layer=final_layer, seed_params=seed_params)
    file_path = os.path.join(full_path, f'best_param_NODE.pt')
    load_params = torch.load(file_path)
    node.load_state_dict(load_params)
# Out:
# Kernel needs to be started by a Jupyter Server. Please use JupyterLab or Classic Notebook while using MATLAB Kernel for Jupyter.

# %% [markdown]
# # Dynamics and Training

# %%
# Run the training loop
for k in range(1):
    seed_data, seed_train = k, 0
    classif = False
    count = 0

    # Create dataset
    datatrain, y, X0, X1 = create_dataloader(distribution, N=N, d=d, noise=noise, seed=seed_data, rescale=rescale)
    print(f'blue: {X0.shape}, red: {X1.shape}')

    while not classif and count < max_count:
        seed_params = 951 # random.randint(1, 1000)
        
        # Setup paths and plotting options
        export_fig, record_freq = True, 20
        if export_fig:
            full_path = create_paths(non_linearity, architecture, d, hidden_dim, num_vals, distribution, N, seed_data, seed_params, rescale)
        
        # Initialize and train the Neural ODE
        print("Training Neural ODE")
        node = NeuralODE(device, fixed_projector, d, hidden_dim, output_dim, non_linearity, adjoint, 
                         architecture, T, num_vals, step_size, method, final_layer, seed_params)
        optimizer = torch.optim.Adam(node.parameters(), lr=learning_rate)
        trainer = Trainer(node, optimizer, device, fixed_projector, loss_func, AdjTrainer=False,
                                    record_freq=record_freq, pathgifs=full_path, verbose=verbose)
        trainer.train(datatrain, max_epochs, full_path)
        
        # Save initial parameters
        variables = [seed_data, seed_params, N, hidden_dim, d, T, num_vals, step_size, learning_rate, non_linearity, loss_func, architecture, max_epochs, random_projector]
        variable_names = ['seed_data', 'seed_params', 'N', 'hidden_dim', 'd', 'T', 'num_vals', 'step_size', 'learning_rate', 'non_linearity', 'loss_func', 'architecture', 'max_epochs', 'Random projector']
        with open(os.path.join(full_path, "InitialValues.json"), "w") as f:
            json.dump(dict(zip(variable_names, variables)), f)
        
        clear_output(wait=True)
        
        # Plot loss and data
        plot_logloss(trainer, full_path, export_fig=True)
        inputs, targets = [], []
        for batch_points, batch_labels in datatrain:
            inputs.append(batch_points)
            targets.append(batch_labels)
        inputs, targets = torch.cat(inputs), torch.cat(targets)
        
        initpts_path = plot_data(node, inputs, targets, N, dpi=400, alpha=0.9, path=full_path, controls = True, init=True, rescale=rescale)
        finalpts_path = plot_data(node, inputs, targets, N, dpi=400, alpha=0.9, path=full_path, controls = True, plot_targets = False, final=True)
        display(Image(filename=initpts_path, width=1000))
        display(Image(filename=finalpts_path, width=1000))
        
        # Visualization of level sets (if d=2)
        # levelsets(node, path=full_path, fig_name=f'Level set',rescale = rescale, step = 0.01, dpi = 800, points = (X0,X1))
        
        # Visualization of trajectories (if d=2)
        num_samples = N  # Number of input points to plot the trajectories
        # inputs, targets = select_random_samples(datatrain, num_samples)
        traj_gif(node, inputs, targets, dpi = 400, path = full_path, fps = 10)
        
        # Summarize the results in a dataframe
        dataframe(trainer, full_path)
        
        if trainer.classif:
            classif = True
            dir_name, file_name = os.path.split(full_path)
            base, ext = os.path.splitext(file_name)
            new_file_name = f"{base} - Achieved{ext}"
            new_path = os.path.join(dir_name, new_file_name)
            os.rename(full_path, new_path)
            full_path = new_path
        else:
            count += 1
            
    if count == max_count:
        dir_name, file_name = os.path.split(full_path)
        base, ext = os.path.splitext(file_name)
        new_file_name = f"{base} - Failed in {max_count} tests{ext}"
        new_path = os.path.join(dir_name, new_file_name)
        os.rename(full_path, new_path)
        break
